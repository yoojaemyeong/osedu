# %% [markdown]
# 1단계: Google Drive 마운트

# %%
from google.colab import drive
drive.mount('/content/g')
# Out:
# Mounted at /content/g

# %%
# !pwd
# Out:
# /content

# %%
# !ls -al
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Apr  2 09:11 .
# drwxr-xr-x 1 root root 4096 Apr  2 09:05 ..
# drwxr-xr-x 1 root root 4096 Jan 16 14:24 .config
# drwx------ 6 root root 4096 Apr  2 09:07 g
# -rw-r--r-- 1 root root  291 Apr  2 09:11 list.txt
# drwxr-xr-x 1 root root 4096 Jan 16 14:24 sample_data

# %%
# !ls -al /content/g/MyDrive

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.5 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.5 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.1
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
# !jupyter kernelspec list
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Available kernels:
#   julia      /root/.local/share/jupyter/kernels/julia
#   ir         /usr/local/share/jupyter/kernels/ir
#   python3    /usr/local/share/jupyter/kernels/python3

# %%
# !jupyter notebook list
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# Currently running servers:

# %%
# !ls -al /usr/local/lib/python3.12/dist-packages/notebook-6.5.7.dist-info/
# Out:
# total 40
# drwxr-xr-x 1 root root  4096 Jan 20 14:55 .
# drwxr-xr-x 1 root root  4096 Jan 20 14:58 ..
# -rw-r--r-- 1 root root   236 Jan 20 14:49 entry_points.txt
# -rw-r--r-- 1 root root     2 Jan 20 14:55 INSTALLER
# -rw-r--r-- 1 root root  2869 Jan 20 14:49 LICENSE
# -rw-r--r-- 1 root root  2496 Jan 20 14:49 METADATA
# -rw-r--r-- 1 root root 20591 Jan 20 14:55 RECORD
# -rw-r--r-- 1 root root     0 Jan 20 14:55 REQUESTED
# -rw-r--r-- 1 root root     9 Jan 20 14:49 top_level.txt
# -rw-r--r-- 1 root root    92 Jan 20 14:49 WHEEL

# %%
# !id
# Out:
# uid=0(root) gid=0(root) groups=0(root)

# %% [markdown]
# 2단계: Github repository clone( gDrive )

# %%
# !git clone https://github.com/yoojaemyeong/gDrive.git
# Out:
# Cloning into 'gDrive'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# 각 드라이브의 상태 보기
# `!ls -al github` 구글 드라이브

# %%
# !ls -al /content/g/MyDrive/
# Out:
# total 20
# dr-x------ 4 root root 4096 Apr  2 09:07 .Encrypted
# drwx------ 2 root root 4096 Apr  2 09:07 MyDrive
# drwx------ 2 root root 4096 Apr  2 09:07 Othercomputers
# dr-x------ 2 root root 4096 Apr  2 09:07 .shortcut-targets-by-id
# drwx------ 5 root root 4096 Apr  2 09:07 .Trash-0

# %%
# !ls -al > list.txt

# %%
# !mv list.txt /content/g/MyDrive/gitdata

# %% [markdown]
# 3단계: Drive 폴더로 이동 ( gDrive --> 구글 드라이브로 이동 )

# %%
# !mv gDrive /content/g/

# %%
# !ls -al /content/g/MyDrive/gitdata/

# %%
# %cd /content/g/MyDrive/gitdata/

# %%
# %%writefile hello.py
print("안녕하세요")
# Out:
# Writing hello.py

# %%
# !python hello.py
# Out:
# 안녕하세요

# %%
# !cat hello.py
# Out:
# print("안녕하세요")

# %%
# !git remote -v
# Out:
# origin	https://github.com/yoojaemyeong/gDrive.git (fetch)
# origin	https://github.com/yoojaemyeong/gDrive.git (push)

# %%
# !git config --global --list
# Out:
# user.name=Yoo Jae Myeong
# user.email=yoojaemyeong@google.com

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git log
# Out:
# commit b8d9166f32e4df4fa77b0257816e9bc34272f9d4 (HEAD -> main)
# Author: Yoo Jae Myeong <yoojaemyeong@example.com>
# Date:   Mon Mar 16 01:53:59 2026 +0000
#
#     Add hello.py
#
# commit f63eb2af23b98fba62bcc42c196f2ef585234460 (origin/main, origin/HEAD)
# Author: Yoo JaeMyeong <45450868+yoojaemyeong@users.noreply.github.com>
# Date:   Mon Mar 16 10:13:44 2026 +0900
#
#     Initial commit

# %%
# !git add hello.py

# %%
# !git commit -m "Add hello.py"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git log --oneline  --all --decorate --graph
# Out:
# * b8d9166 (HEAD -> main) Add hello.py
# * f63eb2a (origin/main, origin/HEAD) Initial commit

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git add hello.py

# %%
# !git commit -m "Add hello.py"
# Out:
# [main b8d9166] Add hello.py
#  1 file changed, 1 insertion(+)
#  create mode 100644 hello.py

# %%
# !git remote set-url origin https://jmyoo-mytoken:본인의토큰을넣을것@github.com/yoojaemyeong/gDrive.git

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 312 bytes | 28.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/yoojaemyeong/gDrive.git
#    f63eb2a..b8d9166  main -> main

# %%
# !pwd
# Out:
# /content

# %%
# !echo $HOME
# Out:
# /root

# %%
# !env
